# %% [markdown]
# # Studio: Working with Databases in Python
#
# For today's studio, we will be using the [TV Shows dataset](https://www.kaggle.com/ruchi798/tv-shows-on-netflix-prime-video-hulu-and-disney) from Kaggle. We have already downloaded the CSV for you.
#
# You will also be using the watchlist you just created to figure out which streaming services contain the shows that you want to watch next so you can decide which one is worth the money to you.
#
# As you complete the different tasks in the studio, you may choose between using Pandas or SQL. Remember that during the prep work, we learned that one is oftentimes more efficient at certain tasks than the other, so choose wisely!

# %% [markdown]
# ## My Watchlist
#
# If you would like, please use this space to make note of your watchlist by editing the text cell.
#
# Ozark
# Schitts Creek
# The Office
# New Girl
# This is Us
# Happy Endings
# Younger
# Good Trouble
# The Bold Type
# Dope Sick

# %% [markdown]
# ## Database Setup
#
# To start with, import the necessary libraries and create a dataframe from the provided CSV. Print the info out for the dataframe. After that, you may drop the column called `Unnamed: 0` and rename any columns with spaces in the names or unusual characters such as `"+"`. Print out the info for the dataframe again to ensure that your changes were effective.

# %%
import pandas as pd
import sqlite3 as sl

data= pd.read_csv("tv_shows.csv")
data= data.drop('Unnamed: 0', 1)
data=data.rename(columns={'Rotten Tomatoes':'Rotten', 'Disney+': 'Disney', 'Prime Video':'Prime'})
data.head()
# Out:
# /var/folders/5v/128x261d72sb4dsy21d7f77c0000gn/T/ipykernel_7125/238617221.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data= data.drop('Unnamed: 0', 1)
#    ID             Title  Year  Age    IMDb   Rotten  Netflix  Hulu  Prime  \
# 0   1      Breaking Bad  2008  18+  9.4/10  100/100        1     0      0
# 1   2   Stranger Things  2016  16+  8.7/10   96/100        1     0      0
# 2   3   Attack on Titan  2013  18+  9.0/10   95/100        1     1      0
# 3   4  Better Call Saul  2015  18+  8.8/10   94/100        1     0      0
# 4   5              Dark  2017  16+  8.8/10   93/100        1     0      0
#
#    Disney  Type
# 0       0     1
# 1       0     1
# 2       0     1
# 3       0     1
# 4       0     1

# %% [markdown]
# With your dataframe at the ready, create a new database called `tv`. Add a new table to your database called `shows` using the data in the dataframe.

# %%
con=sl.connect('tv.db')

# %%
data.to_sql('show1', con)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/5v/128x261d72sb4dsy21d7f77c0000gn/T/ipykernel_7125/2581686842.py in <module>
# ----> 1 data.to_sql('show1', con)
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2223             dtype=dtype,
#    2224         )
# -> 2225         table.create()
#    2226         table.insert(chunksize, method)
#    2227
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py in create(self)
#     856         if self.exists():
#     857             if self.if_exists == "fail":
# --> 858                 raise ValueError(f"Table '{self.name}' already exists.")
#     859             elif self.if_exists == "replace":
#     860                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'show1' already exists.

# %% [markdown]
# With your new table and database set up, print out the top 20 records in the `shows` table.

# %%
print(data.head(20))

with con:
        data1 = con.execute("SELECT * FROM show1 WHERE id<=20")
        for row in data1:
            print(row)
# Out:
#     ID                       Title  Year  Age    IMDb   Rotten  Netflix  Hulu  \
# 0    1                Breaking Bad  2008  18+  9.4/10  100/100        1     0
# 1    2             Stranger Things  2016  16+  8.7/10   96/100        1     0
# 2    3             Attack on Titan  2013  18+  9.0/10   95/100        1     1
# 3    4            Better Call Saul  2015  18+  8.8/10   94/100        1     0
# 4    5                        Dark  2017  16+  8.8/10   93/100        1     0
# 5    6  Avatar: The Last Airbender  2005   7+  9.3/10   93/100        1     0
# 6    7              Peaky Blinders  2013  18+  8.8/10   93/100        1     0
# 7    8            The Walking Dead  2010  18+  8.2/10   93/100        1     0
# 8    9                Black Mirror  2011  18+  8.8/10   92/100        1     0
# 9   10          The Queen's Gambit  2020  18+  8.6/10   92/100        1     0
# 10  11                  Mindhunter  2017  18+  8.6/10   90/100        1     0
# 11  12                   Community  2009   7+  8.5/10   90/100        1     1
# 12  13                      Narcos  2015  18+  8.8/10   90/100        1     0
# 13  14                   Shameless  2011  18+  8.5/10   90/100        1     1
# 14  15                 Money Heist  2017  18+  8.3/10   90/100        1     0
# 15  16          Marvel's Daredevil  2015  18+  8.6/10   90/100        1     0
# 16  17                     Lucifer  2016  16+  8.1/10   90/100        1     0
# 17  18                Supernatural  2005  16+  8.4/10   89/100        1     0
# 18  19                 The Witcher  2019  18+  8.2/10   89/100        1     0
# 19  20                       Ozark  2017  18+  8.4/10   89/100        1     0
#
#     Prime  Disney  Type
# 0       0       0     1
# 1       0       0     1
# 2       0       0     1
# 3       0       0     1
# 4       0       0     1
# 5       1       0     1
# 6       0       0     1
# 7       0       0     1
# 8       0       0     1
# 9       0       0     1
# 10      0       0     1
# 11      1       0     1
# 12      0       0     1
# 13      1       0     1
# 14      0       0     1
# 15      0       0     1
# 16      0       0     1
# 17      0       0     1
# 18      0       0     1
# 19      0       0     1
# (0, 1, 'Breaking Bad', 2008, '18+', '9.4/10', '100/100', 1, 0, 0, 0, 1)
# (1, 2, 'Stranger Things', 2016, '16+', '8.7/10', '96/100', 1, 0, 0, 0, 1)
# (2, 3, 'Attack on Titan', 2013, '18+', '9.0/10', '95/100', 1, 1, 0, 0, 1)
# (3, 4, 'Better Call Saul', 2015, '18+', '8.8/10', '94/100', 1, 0, 0, 0, 1)
# (4, 5, 'Dark', 2017, '16+', '8.8/10', '93/100', 1, 0, 0, 0, 1)
# (5, 6, 'Avatar: The Last Airbender', 2005, '7+', '9.3/10', '93/100', 1, 0, 1, 0, 1)
# (6, 7, 'Peaky Blinders', 2013, '18+', '8.8/10', '93/100', 1, 0, 0, 0, 1)
# (7, 8, 'The Walking Dead', 2010, '18+', '8.2/10', '93/100', 1, 0, 0, 0, 1)
# (8, 9, 'Black Mirror', 2011, '18+', '8.8/10', '92/100', 1, 0, 0, 0, 1)
# (9, 10, "The Queen's Gambit", 2020, '18+', '8.6/10', '92/100', 1, 0, 0, 0, 1)
# (10, 11, 'Mindhunter', 2017, '18+', '8.6/10', '90/100', 1, 0, 0, 0, 1)
# (11, 12, 'Community', 2009, '7+', '8.5/10', '90/100', 1, 1, 1, 0, 1)
# (12, 13, 'Narcos', 2015, '18+', '8.8/10', '90/100', 1, 0, 0, 0, 1)
# (13, 14, 'Shameless', 2011, '18+', '8.5/10', '90/100', 1, 1, 1, 0, 1)
# (14, 15, 'Money Heist', 2017, '18+', '8.3/10', '90/100', 1, 0, 0, 0, 1)
# (15, 16, "Marvel's Daredevil", 2015, '18+', '8.6/10', '90/100', 1, 0, 0, 0, 1)
# (16, 17, 'Lucifer', 2016, '16+', '8.1/10', '90/100', 1, 0, 0, 0, 1)
# (17, 18, 'Supernatural', 2005, '16+', '8.4/10', '89/100', 1, 0, 0, 0, 1)
# (18, 19, 'The Witcher', 2019, '18+', '8.2/10', '89/100', 1, 0, 0, 0, 1)
# (19, 20, 'Ozark', 2017, '18+', '8.4/10', '89/100', 1, 0, 0, 0, 1)

# %% [markdown]
# Now add a table that includes an id number and the titles on your watchlist.

# %%
with con:
    con.execute('''
        CREATE TABLE watchlist2(
            id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
            title TEXT
        );
    ''')
    
    sql= 'INSERT INTO watchlist2 (id, title) values (?, ?)'
    data2=[
        (1, 'Ozark'),
        (2, 'Schitts Creek'),
        (3, 'The Office'),
        (4, 'New Girl'),
        (5, 'This is Us'),
        (6, 'Happy Endings'),
        (7, 'Younger'),
        (8, 'Good Trouble'),
        (9, 'The Bold Type'),
        (10, 'Dope Sick')
    ]
    
    con.executemany(sql, data2)
    data3=(con.execute('SELECT * FROM watchlist2'))
    for row in data3:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /var/folders/5v/128x261d72sb4dsy21d7f77c0000gn/T/ipykernel_7125/4006710142.py in <module>
#       1 with con:
# ----> 2     con.execute('''
#       3         CREATE TABLE watchlist2(
#       4             id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
#       5             title TEXT
#
# OperationalError: table watchlist2 already exists

# %% [markdown]
# ## Working with the Data
#
# Using either Pandas or SQL, determine how many shows are on each streaming service and what the mean is for each streaming service.
#
# **Note**: You may notice that the mean represents the percentage of shows in the dataframe that are on each streaming service. Take a moment to think about why that is.

# %%
print(data['Rotten'].value_counts())
print(data['Netflix'].value_counts())
print(data['Hulu'].value_counts())
print(data['Disney'].value_counts())
print(data['Prime'].value_counts())
# Out:
# 10/100     304
# 13/100     174
# 45/100     135
# 51/100     131
# 52/100     125
#           ...
# 91/100       4
# 94/100       2
# 95/100       2
# 100/100      2
# 96/100       1
# Name: Rotten, Length: 85, dtype: int64
# 0    3397
# 1    1971
# Name: Netflix, dtype: int64
# 0    3747
# 1    1621
# Name: Hulu, dtype: int64
# 0    5017
# 1     351
# Name: Disney, dtype: int64
# 0    3537
# 1    1831
# Name: Prime, dtype: int64

# %% [markdown]
# Join your watchlist data with the shows data to determine which streaming services your watchlist shows are on and make a new table in your database using the joined data. Print out the data in your joined table to see what shows on your watchlist on in the original dataset. With the joined data, determine the percentage of your watchlist shows that are on each streaming service and how many of your watchlist shows are on each streaming service.

# %%
with con:
    join_data=con.execute('''SELECT * 
                             FROM show1
                             LEFT JOIN watchlist2
                             ON show1.title=watchlist2.title
                        ;''')
    
    for row in join_data:
        print(row)
# Out:
# (0, 1, 'Breaking Bad', 2008, '18+', '9.4/10', '100/100', 1, 0, 0, 0, 1, None, None)
# (1, 2, 'Stranger Things', 2016, '16+', '8.7/10', '96/100', 1, 0, 0, 0, 1, None, None)
# (2, 3, 'Attack on Titan', 2013, '18+', '9.0/10', '95/100', 1, 1, 0, 0, 1, None, None)
# (3, 4, 'Better Call Saul', 2015, '18+', '8.8/10', '94/100', 1, 0, 0, 0, 1, None, None)
# (4, 5, 'Dark', 2017, '16+', '8.8/10', '93/100', 1, 0, 0, 0, 1, None, None)
# (5, 6, 'Avatar: The Last Airbender', 2005, '7+', '9.3/10', '93/100', 1, 0, 1, 0, 1, None, None)
# (6, 7, 'Peaky Blinders', 2013, '18+', '8.8/10', '93/100', 1, 0, 0, 0, 1, None, None)
# (7, 8, 'The Walking Dead', 2010, '18+', '8.2/10', '93/100', 1, 0, 0, 0, 1, None, None)
# (8, 9, 'Black Mirror', 2011, '18+', '8.8/10', '92/100', 1, 0, 0, 0, 1, None, None)
# (9, 10, "The Queen's Gambit", 2020, '18+', '8.6/10', '92/100', 1, 0, 0, 0, 1, None, None)
# (10, 11, 'Mindhunter', 2017, '18+', '8.6/10', '90/100', 1, 0, 0, 0, 1, None, None)
# (11, 12, 'Community', 2009, '7+', '8.5/10', '90/100', 1, 1, 1, 0, 1, None, None)
# (12, 13, 'Narcos', 2015, '18+', '8.8/10', '90/100', 1, 0, 0, 0, 1, None, None)
# (13, 14, 'Shameless', 2011, '18+', '8.5/10', '90/100', 1, 1, 1, 0, 1, None, None)
# (14, 15, 'Money Heist', 2017, '18+', '8.3/10', '90/100', 1, 0, 0, 0, 1, None, None)
# (15, 16, "Marvel's Daredevil", 2015, '18+', '8.6/10', '90/100', 1, 0, 0, 0, 1, None, None)
# (16, 17, 'Lucifer', 2016, '16+', '8.1/10', '90/100', 1, 0, 0, 0, 1, None, None)
# (17, 18, 'Supernatural', 2005, '16+', '8.4/10', '89/100', 1, 0, 0, 0, 1, None, None)
# (18, 19, 'The Witcher', 2019, '18+', '8.2/10', '89/100', 1, 0, 0, 0, 1, None, None)
# (19, 20, 'Ozark', 2017, '18+', '8.4/10', '89/100', 1, 0, 0, 0, 1, 1, 'Ozark')
# (20, 21, 'The Crown', 2016, '18+', '8.6/10', '89/100', 1, 0, 0, 0, 1, None, None)
# (21, 22, 'Cobra Kai', 2018, '16+', '8.6/10', '89/100', 1, 0, 0, 0, 1, None, None)
# (22, 23, 'The Blacklist', 2013, '16+', '8.0/10', '88/100', 1, 0, 0, 0, 1, None, None)
# (23, 24, 'The Flash', 2014, '16+', '7.6/10', '88/100', 1, 0, 0, 0, 1, None, None)
# (24, 25, 'Outlander', 2014, '18+', '8.4/10', '88/100', 1, 0, 0, 0, 1, None, None)
# (25, 26, 'Fullmetal Alchemist: Brotherhood', 2009, '16+', '9.1/10', '88/100', 1, 1, 0, 0, 1, None, None)
# (26, 27, 'The Good Place', 2016, '16+', '8.2/10', '88/100', 1, 0, 0, 0, 1, None, None)
# (27, 28, 'House of Cards', 2013, '18+', '8.7/10', '88/100', 1, 0, 0, 0, 1, None, None)
# (28, 29, 'Atypical', 2017, '16+', '8.3/10', '88/100', 1, 0, 0, 0, 1, None, None)
# (29, 30, "Grey's Anatomy", 2005, '16+', '7.5/10', '87/100', 1, 1, 0, 0, 1, None, None)
# (30, 31, 'Arrested Development', 2003, '16+', '8.7/10', '87/100', 1, 1, 0, 0, 1, None, None)
# (31, 32, 'Lupin', 2021, '18+', '7.5/10', '87/100', 1, 0, 0, 0, 1, None, None)
# (32, 33, 'The Umbrella Academy', 2019, '16+', '8.0/10', '87/100', 1, 0, 0, 0, 1, None, None)
# (33, 34, 'Orange Is the New Black', 2013, '18+', '8.0/10', '87/100', 1, 0, 0, 0, 1, None, None)
# (34, 35, 'The Vampire Diaries', 2009, '16+', '7.7/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (35, 36, 'Demon Slayer: Kimetsu no Yaiba', 2019, '18+', '8.7/10', '86/100', 1, 1, 0, 0, 1, None, None)
# (36, 37, 'The Last Dance', 2020, '16+', '9.1/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (37, 38, 'American Horror Story', 2011, '18+', '8.0/10', '86/100', 1, 1, 1, 0, 1, None, None)
# (38, 39, 'Elite', 2018, '18+', '7.5/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (39, 40, 'BoJack Horseman', 2014, '18+', '8.7/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (40, 41, 'Star Trek: The Next Generation', 1987, '7+', '8.6/10', '86/100', 1, 1, 1, 0, 1, None, None)
# (41, 42, 'Broadchurch', 2013, '18+', '8.4/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (42, 43, 'The IT Crowd', 2006, '16+', '8.5/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (43, 44, 'When They See Us', 2019, '18+', '8.9/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (44, 45, 'Love, Death & Robots', 2019, '18+', '8.5/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (45, 46, "Schitt's Creek", 2015, '16+', '8.5/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (46, 47, "Marvel's Agents of S.H.I.E.L.D.", 2013, '16+', '7.5/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (47, 48, 'Never Have I Ever', 2020, '16+', '7.9/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (48, 49, 'The 100', 2014, '16+', '7.6/10', '86/100', 1, 0, 0, 0, 1, None, None)
# (49, 50, 'American Crime Story', 2016, '18+', '8.4/10', '85/100', 1, 0, 0, 0, 1, None, None)
# (50, 51, 'The Last Kingdom', 2015, '18+', '8.4/10', '85/100', 1, 0, 0, 0, 1, None, None)
# (51, 52, 'The End of the F***ing World', 2017, '18+', '8.1/10', '85/100', 1, 0, 0, 0, 1, None, None)
# (52, 53, 'New Girl', 2011, '16+', '7.7/10', '85/100', 1, 0, 0, 0, 1, 4, 'New Girl')
# (53, 54, 'Penny Dreadful', 2014, '18+', '8.2/10', '85/100', 1, 0, 1, 0, 1, None, None)
# (54, 55, 'One Piece', 1999, '7+', '8.8/10', '85/100', 1, 1, 0, 0, 1, None, None)
# (55, 56, "Marvel's The Punisher", 2017, '18+', '8.5/10', '85/100', 1, 0, 0, 0, 1, None, None)
# (56, 57, 'Evil', 2019, '18+', '7.7/10', '85/100', 1, 0, 0, 0, 1, None, None)
# (57, 58, 'YOU', 2018, '18+', '7.7/10', '85/100', 1, 0, 0, 0, 1, None, None)
# (58, 59, 'Sense8', 2015, '18+', '8.3/10', '84/100', 1, 0, 0, 0, 1, None, None)
# (59, 60, 'Making a Murderer', 2015, '16+', '8.6/10', '84/100', 1, 0, 0, 0, 1, None, None)
# (60, 61, 'Unbelievable', 2019, '18+', '8.4/10', '84/100', 1, 0, 0, 0, 1, None, None)
# (61, 62, 'Arrow', 2012, '16+', '7.5/10', '84/100', 1, 0, 0, 0, 1, None, None)
# (62, 63, 'Sex Education', 2019, '18+', '8.3/10', '84/100', 1, 0, 0, 0, 1, None, None)
# (63, 64, "Marvel's Jessica Jones", 2015, '18+', '7.9/10', '84/100', 1, 0, 0, 0, 1, None, None)
# (64, 65, 'Sweet Tooth', 2021, '16+', '7.9/10', '84/100', 1, 0, 0, 0, 1, None, None)
# (65, 66, 'Good Girls', 2018, '16+', '7.8/10', '84/100', 1, 1, 0, 0, 1, None, None)
# (66, 67, 'Death Note', 2006, '16+', '9.0/10', '84/100', 1, 1, 0, 0, 1, None, None)
# (67, 68, 'Gilmore Girls', 2000, '16+', '8.1/10', '84/100', 1, 0, 0, 0, 1, None, None)
# (68, 69, 'The Legend of Korra', 2012, '7+', '8.4/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (69, 70, 'How to Get Away with Murder', 2014, '16+', '8.1/10', '83/100', 1, 1, 0, 0, 1, None, None)
# (70, 71, 'Master of None', 2015, '18+', '8.3/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (71, 72, "Chappelle's Show", 2003, '18+', '8.7/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (72, 73, 'One-Punch Man', 2015, '7+', '8.8/10', '83/100', 1, 1, 0, 0, 1, None, None)
# (73, 74, 'Downton Abbey', 2010, '16+', '8.7/10', '83/100', 1, 0, 1, 0, 1, None, None)
# (74, 75, 'Gotham', 2014, '16+', '7.8/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (75, 76, 'Pose', 2018, '18+', '8.6/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (76, 77, 'Bodyguard', 2018, '18+', '8.1/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (77, 78, 'Altered Carbon', 2018, '18+', '8.0/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (78, 79, 'Ash vs Evil Dead', 2015, '18+', '8.4/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (79, 80, 'The Sinner', 2017, '16+', '7.9/10', '83/100', 1, 0, 0, 0, 1, None, None)
# (80, 81, 'Our Planet', 2019, 'all', '9.3/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (81, 82, 'Narcos: Mexico', 2018, '18+', '8.4/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (82, 83, 'Shadow and Bone', 2021, '16+', '7.7/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (83, 84, 'Castlevania', 2017, '18+', '8.3/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (84, 85, 'Star Trek', 1966, '7+', '8.3/10', '82/100', 1, 1, 1, 0, 1, None, None)
# (85, 86, 'The Kominsky Method', 2018, '18+', '8.2/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (86, 87, 'Hunter x Hunter', 2011, '16+', '9.0/10', '82/100', 1, 1, 0, 0, 1, None, None)
# (87, 88, 'Dead to Me', 2019, '18+', '8.0/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (88, 89, 'The Haunting of Hill House', 2018, '18+', '8.6/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (89, 90, 'Russian Doll', 2019, '18+', '7.9/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (90, 91, 'Kingdom', 2019, '18+', '8.4/10', '82/100', 1, 1, 0, 0, 1, None, None)
# (91, 92, 'Neon Genesis Evangelion', 1995, '16+', '8.5/10', '82/100', 1, 0, 0, 0, 1, None, None)
# (92, 93, 'Naruto', 2002, '7+', '8.3/10', '81/100', 1, 1, 0, 0, 1, None, None)
# (93, 94, 'NCIS', 2003, '16+', '7.7/10', '81/100', 1, 0, 0, 0, 1, None, None)
# (94, 95, 'Manifest', 2018, '16+', '7.2/10', '81/100', 1, 1, 0, 0, 1, None, None)
# (95, 96, 'Halt and Catch Fire', 2014, '16+', '8.4/10', '81/100', 1, 0, 0, 0, 1, None, None)
# (96, 97, "Monty Python's Flying Circus", 1969, '16+', '8.8/10', '81/100', 1, 0, 0, 0, 1, None, None)
# (97, 98, 'After Life', 2019, '18+', '8.4/10', '81/100', 1, 0, 0, 0, 1, None, None)
# (98, 99, 'Riverdale', 2017, '16+', '6.8/10', '81/100', 1, 1, 0, 0, 1, None, None)
# (99, 100, 'Big Mouth', 2017, '18+', '7.9/10', '81/100', 1, 0, 0, 0, 1, None, None)
# (100, 101, 'I Think You Should Leave with Tim Robinson', 2019, '18+', '7.8/10', '81/100', 1, 0, 0, 0, 1, None, None)
# (101, 102, 'Derry Girls', 2018, '16+', '8.4/10', '81/100', 1, 0, 0, 0, 1, None, None)
# (102, 103, 'The Promised Neverland', 2019, '18+', '8.5/10', '81/100', 1, 1, 0, 0, 1, None, None)
# (103, 104, 'Lost in Space', 2018, '7+', '7.3/10', '80/100', 1, 1, 0, 0, 1, None, None)
# (104, 105, 'Star Trek: Deep Space Nine', 1993, '7+', '8.0/10', '80/100', 1, 1, 1, 0, 1, None, None)
# (105, 106, 'Jane the Virgin', 2014, '16+', '7.8/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (106, 107, 'Godless', 2017, '18+', '8.3/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (107, 108, 'The OA', 2016, '18+', '7.8/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (108, 109, "DC's Legends of Tomorrow", 2016, '16+', '6.8/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (109, 110, 'Sacred Games', 2018, '18+', '8.6/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (110, 111, 'iZombie', 2015, '16+', '7.8/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (111, 112, 'Longmire', 2012, '16+', '8.3/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (112, 113, 'Happy Endings', 2011, '16+', '7.7/10', '80/100', 1, 1, 0, 0, 1, 6, 'Happy Endings')
# (113, 114, 'Into the Badlands', 2015, '16+', '8.0/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (114, 115, 'The Originals', 2013, '16+', '8.2/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (115, 116, 'Anne with an E', 2017, 'all', '8.7/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (116, 117, 'Grace and Frankie', 2015, '18+', '8.3/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (117, 118, 'Chilling Adventures of Sabrina', 2018, '16+', '7.5/10', '80/100', 1, 0, 0, 0, 1, None, None)
# (118, 119, 'Queen of the South', 2016, '16+', '8.0/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (119, 120, 'A Series of Unfortunate Events', 2017, '7+', '7.8/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (120, 121, 'Bridgerton', 2020, None, '7.3/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (121, 122, 'Unorthodox', 2020, '18+', '8.0/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (122, 123, 'Stargate SG-1', 1997, '13+', '8.4/10', '79/100', 1, 1, 0, 0, 1, None, None)
# (123, 124, 'Outer Banks', 2020, '18+', '7.6/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (124, 125, '13 Reasons Why', 2017, '18+', '7.6/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (125, 126, 'Unbreakable Kimmy Schmidt', 2015, '16+', '7.6/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (126, 127, "Marvel's Luke Cage", 2016, '18+', '7.3/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (127, 128, 'GLOW', 2017, '18+', '8.0/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (128, 129, 'Borgen', 2010, '18+', '8.5/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (129, 130, 'The 4400', 2004, '7+', '7.3/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (130, 131, 'Alias Grace', 2017, '18+', '7.7/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (131, 132, 'All American', 2018, '16+', '7.7/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (132, 133, 'Santa Clarita Diet', 2017, '18+', '7.8/10', '79/100', 1, 0, 0, 0, 1, None, None)
# (133, 134, 'Reign', 2013, '16+', '7.5/10', '78/100', 1, 0, 0, 0, 1, None, None)
# (134, 135, 'Maniac', 2018, '18+', '7.8/10', '78/100', 1, 0, 0, 0, 1, None, None)
# (135, 136, 'Dark Matter', 2015, '18+', '7.5/10', '78/100', 1, 0, 1, 0, 1, None, None)
# (136, 137, 'Star Trek: Voyager', 1995, '7+', '7.8/10', '78/100', 1, 1, 1, 0, 1, None, None)
# (137, 138, 'Tiger King: Murder, Mayhem and Madness', 2020, '18+', '7.6/10', '78/100', 1, 0, 0, 0, 1, None, None)
# (138, 139, 'Call the Midwife', 2012, '16+', '8.4/10', '78/100', 1, 0, 0, 0, 1, None, None)
# (139, 140, 'Queer Eye', 2018, '16+', '8.5/10', '78/100', 1, 0, 0, 0, 1, None, None)
# (140, 141, 'American Vandal', 2017, '16+', '8.2/10', '78/100', 1, 0, 0, 0, 1, None, None)
# (141, 142, 'Wynonna Earp', 2016, '16+', '7.5/10', '78/100', 1, 0, 0, 0, 1, None, None)
# (142, 143, "Marvel's The Defenders", 2017, '18+', '7.3/10', '78/100', 1, 0, 0, 0, 1, None, None)
# (143, 144, 'HAPPY!', 2017, '18+', '8.2/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (144, 145, 'Haikyu!!', 2014, '16+', '8.7/10', '77/100', 1, 1, 0, 0, 1, None, None)
# (145, 146, 'Colony', 2016, '16+', '7.4/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (146, 147, 'Heartland', 2007, '7+', '8.4/10', '77/100', 1, 0, 1, 0, 1, None, None)
# (147, 148, 'Alone', 2015, '16+', '8.4/10', '77/100', 1, 1, 0, 0, 1, None, None)
# (148, 149, 'Marco Polo', 2014, '18+', '8.0/10', '77/100', 1, 0, 1, 0, 1, None, None)
# (149, 150, 'Wild Wild Country', 2018, '16+', '8.1/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (150, 151, 'The Dragon Prince', 2018, '7+', '8.4/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (151, 152, 'Locke & Key', 2020, '16+', '7.4/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (152, 153, 'Love', 2016, '18+', '7.7/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (153, 154, 'One Day at a Time', 2017, '7+', '8.2/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (154, 155, 'Feel Good', 2020, '18+', '7.5/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (155, 156, 'Fauda', 2015, '16+', '8.2/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (156, 157, 'The Dark Crystal: Age of Resistance', 2019, '7+', '8.4/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (157, 158, 'Top Boy', 2011, '18+', '8.4/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (158, 159, 'I Am Not Okay with This', 2020, '18+', '7.5/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (159, 160, 'Supergirl', 2015, '16+', '6.2/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (160, 161, 'The Shannara Chronicles', 2016, '16+', '7.2/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (161, 162, 'Designated Survivor', 2016, '7+', '7.5/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (162, 163, 'Travelers', 2016, '16+', '8.1/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (163, 164, 'StartUp', 2016, '18+', '7.9/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (164, 165, 'Ripper Street', 2012, '18+', '8.1/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (165, 166, 'Episodes', 2011, '18+', '7.8/10', '77/100', 1, 0, 0, 0, 1, None, None)
# (166, 167, 'Crazy Ex-Girlfriend', 2015, '16+', '7.8/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (167, 168, 'Bloodline', 2015, '18+', '7.9/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (168, 169, 'Black Summer', 2019, '18+', '6.5/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (169, 170, 'The Borgias', 2011, '18+', '7.9/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (170, 171, 'Glee', 2009, '16+', '6.7/10', '76/100', 1, 0, 1, 0, 1, None, None)
# (171, 172, 'The Stranger', 2020, '18+', '7.3/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (172, 173, 'Virgin River', 2019, '16+', '7.4/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (173, 174, 'Lilyhammer', 2012, '18+', '8.0/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (174, 175, 'Dirty John', 2018, '18+', '7.2/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (175, 176, "TURN: Washington's Spies", 2014, '16+', '8.1/10', '76/100', 1, 0, 0, 0, 1, None, None)
# (176, 177, 'Star Trek: Enterprise', 2001, '7+', '7.5/10', '76/100', 1, 1, 1, 0, 1, None, None)
# (177, 178, 'She-Ra and the Princesses of Power', 2018, 'all', '7.9/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (178, 179, 'Merlin', 2008, '7+', '7.9/10', '75/100', 1, 1, 1, 0, 1, None, None)
# (179, 180, 'The Magicians', 2015, '16+', '7.6/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (180, 181, 'Ginny & Georgia', 2021, '16+', '7.5/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (181, 182, 'The Spy', 2019, '18+', '7.9/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (182, 183, 'On My Block', 2018, '16+', '8.0/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (183, 184, 'The Movies That Made Us', 2019, '18+', '7.8/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (184, 185, "Chef's Table", 2015, 'all', '8.5/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (185, 186, 'Biohackers', 2020, '18+', '6.8/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (186, 187, 'The Seven Deadly Sins', 2014, '16+', '8.0/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (187, 188, 'The Keepers', 2017, '16+', '8.1/10', '75/100', 1, 0, 0, 0, 1, None, None)
# (188, 189, 'F is for Family', 2015, '18+', '8.0/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (189, 190, 'The Midnight Gospel', 2020, '18+', '8.2/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (190, 191, 'Ragnarok', 2020, '18+', '7.5/10', '74/100', 1, 0, 1, 0, 1, None, None)
# (191, 192, 'Legacies', 2018, '16+', '7.4/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (192, 193, 'The Order', 2019, '18+', '6.8/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (193, 194, 'Disenchantment', 2018, '16+', '7.2/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (194, 195, 'Dead Set', 2008, '18+', '7.6/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (195, 196, 'Dirty Money', 2018, '16+', '8.1/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (196, 197, 'The Staircase', 2005, '16+', '7.9/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (197, 198, 'Soul Eater', 2008, '16+', '7.8/10', '74/100', 1, 1, 0, 0, 1, None, None)
# (198, 199, 'Into the Night', 2020, '18+', '7.1/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (199, 200, 'The Haunting of Bly Manor', 2020, None, '7.4/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (200, 201, 'Julie and the Phantoms', 2020, '7+', '8.5/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (201, 202, 'Leyla ile Mecnun', 2011, '7+', '9.1/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (202, 203, 'Living with Yourself', 2019, '18+', '7.2/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (203, 204, 'Young Royals', 2021, None, '8.6/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (204, 205, 'Hilda', 2018, '7+', '8.6/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (205, 206, 'The Mechanism', 2018, '18+', '8.4/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (206, 207, 'ERASED', 2016, '16+', '8.5/10', '74/100', 1, 1, 0, 0, 1, None, None)
# (207, 208, 'Formula 1: Drive to Survive', 2019, '16+', '8.6/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (208, 209, "Don't F**k with Cats: Hunting an Internet Killer", 2019, '18+', '8.0/10', '74/100', 1, 0, 0, 0, 1, None, None)
# (209, 210, "Kim's Convenience", 2016, '16+', '8.2/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (210, 211, 'The Society', 2019, '18+', '7.1/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (211, 212, 'Imposters', 2017, '16+', '7.8/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (212, 213, 'Frequency', 2016, '7+', '7.5/10', '73/100', 1, 0, 1, 0, 1, None, None)
# (213, 214, 'Wentworth', 2013, '18+', '8.6/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (214, 215, "Marvel's Iron Fist", 2017, '18+', '6.5/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (215, 216, 'Bleach', 2004, '18+', '8.1/10', '73/100', 1, 1, 0, 0, 1, None, None)
# (216, 217, 'Quantico', 2015, '16+', '6.7/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (217, 218, 'Shooter', 2016, '16+', '7.5/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (218, 219, 'Pokémon', 1997, '7+', '7.5/10', '73/100', 1, 1, 1, 0, 1, None, None)
# (219, 220, 'Hollywood', 2020, '18+', '7.5/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (220, 221, 'Madam Secretary', 2014, '16+', '7.6/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (221, 222, 'Last Tango in Halifax', 2012, '16+', '8.3/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (222, 223, 'Safe', 2018, '18+', '7.3/10', '73/100', 1, 1, 0, 0, 1, None, None)
# (223, 224, 'Resurrection: Ertugrul', 2014, '16+', '8.0/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (224, 225, 'Versailles', 2015, '18+', '7.9/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (225, 226, 'Sex/Life', 2021, '18+', '5.4/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (226, 227, 'Fullmetal Alchemist', 2003, '16+', '8.5/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (227, 228, 'Marianne', 2019, '18+', '7.5/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (228, 229, 'Five Came Back', 2017, '16+', '8.3/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (229, 230, 'Miraculous: Tales of Ladybug & Cat Noir', 2015, '7+', '7.7/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (230, 231, 'Abstract: The Art of Design', 2017, '16+', '8.4/10', '73/100', 1, 0, 0, 0, 1, None, None)
# (231, 232, 'Teenage Bounty Hunters', 2020, '18+', '7.7/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (232, 233, 'Documentary Now!', 2015, '18+', '8.1/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (233, 234, 'Special', 2019, '18+', '7.6/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (234, 235, "JoJo's Bizarre Adventure", 2012, '18+', '8.4/10', '72/100', 1, 1, 0, 0, 1, None, None)
# (235, 236, 'Manhunt', 2017, '16+', '8.1/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (236, 237, 'Your Lie in April', 2014, '7+', '8.6/10', '72/100', 1, 1, 0, 0, 1, None, None)
# (237, 238, 'Code Geass: Lelouch of the Rebellion', 2006, '18+', '8.7/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (238, 239, 'Middleditch & Schwartz', 2020, '18+', '8.6/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (239, 240, 'Zoo', 2015, '16+', '6.7/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (240, 241, 'Jupiters Legacy', 2021, '18+', '6.7/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (241, 242, 'Ratched', 2020, '18+', '7.3/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (242, 243, 'Babylon Berlin', 2017, '18+', '8.4/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (243, 244, 'Better Than Us', 2018, None, '7.4/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (244, 245, 'Everything Sucks!', 2018, '16+', '7.5/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (245, 246, 'Evil Genius', 2018, '18+', '7.5/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (246, 247, 'Doctor Foster', 2015, '16+', '7.7/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (247, 248, 'Marcella', 2016, '18+', '7.4/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (248, 249, 'Survivor', 2000, '7+', '7.2/10', '72/100', 1, 1, 1, 0, 1, None, None)
# (249, 250, 'Derek', 2013, '7+', '8.0/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (250, 251, 'Flowers', 2016, None, '8.2/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (251, 252, '3%', 2016, '18+', '7.4/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (252, 253, 'Tuca & Bertie', 2019, '18+', '7.4/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (253, 254, "Kuroko's Basketball", 2012, None, '8.3/10', '72/100', 1, 0, 0, 0, 1, None, None)
# (254, 255, 'Parasyte -the maxim-', 2014, '18+', '8.3/10', '72/100', 1, 1, 0, 0, 1, None, None)
# (255, 256, 'Last Chance U', 2016, '16+', '8.4/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (256, 257, 'Trailer Park Boys', 2001, '18+', '8.5/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (257, 258, 'Black Lightning', 2018, '16+', '6.1/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (258, 259, 'Chicago Med', 2015, '16+', '7.6/10', '71/100', 1, 1, 0, 0, 1, None, None)
# (259, 260, 'How to Sell Drugs Online (Fast)', 2019, '18+', '7.9/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (260, 261, 'Secret City', 2016, '18+', '7.4/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (261, 262, 'Dynasty', 2017, '16+', '7.3/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (262, 263, 'Dracula', 2020, '18+', '6.8/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (263, 264, 'Delhi Crime', 2019, None, '8.5/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (264, 265, 'Space Force', 2020, '18+', '6.7/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (265, 266, "Pretend It's a City", 2021, '16+', '8.1/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (266, 267, 'Masters of the Universe: Revelation', 2021, '7+', '4.9/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (267, 268, 'iCarly', 2007, 'all', '6.7/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (268, 269, 'Who Killed Sara?', 2021, '18+', '6.4/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (269, 270, 'Sword Art Online', 2012, '18+', '7.6/10', '71/100', 1, 1, 0, 0, 1, None, None)
# (270, 271, 'Paranormal', 2020, '7+', '8.5/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (271, 273, 'Frontier', 2016, '18+', '7.2/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (272, 274, 'The Politician', 2019, '16+', '7.5/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (273, 275, 'Raising Dion', 2019, '7+', '7.2/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (274, 276, 'Food Wars! Shokugeki no Soma', 2015, '18+', '8.2/10', '71/100', 1, 1, 0, 0, 1, None, None)
# (275, 277, 'Crash Landing on You', 2019, '16+', '8.7/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (276, 278, 'Seven Seconds', 2018, '18+', '7.7/10', '71/100', 1, 0, 0, 0, 1, None, None)
# (277, 279, 'The Great British Bake Off', 2010, '7+', '8.5/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (278, 280, 'Wizards: Tales of Arcadia', 2020, '7+', '8.2/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (279, 281, 'Conversations with a Killer: The Ted Bundy Tapes', 2019, '18+', '7.8/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (280, 282, 'Lenox Hill', 2020, None, '8.7/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (281, 283, 'Fate: The Winx Saga', 2021, '18+', '6.9/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (282, 284, 'The Circle', 2020, '18+', '7.3/10', '70/100', 1, 0, 1, 0, 1, None, None)
# (283, 285, 'Cheer', 2020, '16+', '8.1/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (284, 286, 'Hemlock Grove', 2013, '18+', '7.1/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (285, 287, 'Transformers: War for Cybertron: Siege', 2020, '16+', '7.4/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (286, 288, 'Explained', 2018, '16+', '8.0/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (287, 289, 'Messiah', 2020, '18+', '7.6/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (288, 290, 'Sky Rojo', 2021, '18+', '6.5/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (289, 291, 'Bonding', 2019, '18+', '7.2/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (290, 292, "I'm Sorry", 2017, '7+', '8.0/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (291, 293, 'Katla', 2021, '18+', '7.1/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (292, 294, "It's Okay to Not Be Okay", 2020, '16+', '8.8/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (293, 295, 'Forensic Files', 1996, '16+', '8.8/10', '70/100', 1, 1, 1, 0, 1, None, None)
# (294, 296, "Workin' Moms", 2017, '18+', '7.6/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (295, 297, 'The Toys That Made Us', 2017, '16+', '8.1/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (296, 298, 'The Devil Next Door', 2019, '18+', '7.6/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (297, 299, 'Kipo and the Age of Wonderbeasts', 2020, '7+', '8.4/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (298, 300, 'Roswell, New Mexico', 2019, '16+', '6.2/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (299, 301, 'Night Stalker: The Hunt For a Serial Killer', 2021, '18+', '7.5/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (300, 302, 'Glitch', 2015, '16+', '7.3/10', '70/100', 1, 0, 0, 0, 1, None, None)
# (301, 303, 'Great Pretender', 2020, '18+', '8.0/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (302, 304, 'InuYasha', 2000, '16+', '7.9/10', '69/100', 1, 1, 0, 0, 1, None, None)
# (303, 305, 'In the Dark', 2019, '16+', '7.5/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (304, 306, 'GHOUL', 2018, '18+', '7.1/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (305, 307, 'Nailed It!', 2018, '7+', '7.4/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (306, 308, 'Voltron: Legendary Defender', 2016, '7+', '8.1/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (307, 309, 'Trollhunters: Tales of Arcadia', 2016, '7+', '8.4/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (308, 310, 'Sweet Magnolias', 2020, '16+', '7.4/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (309, 311, 'Medici: Masters of Florence', 2016, '7+', '7.9/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (310, 312, 'The Innocent', 2021, None, '7.9/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (311, 313, 'Aggretsuko', 2018, '16+', '8.1/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (312, 314, 'Jurassic World: Camp Cretaceous', 2020, '7+', '7.5/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (313, 315, 'Rake', 2010, '16+', '8.5/10', '69/100', 1, 1, 1, 0, 1, None, None)
# (314, 316, 'The Serpent', 2021, None, '7.6/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (315, 317, 'The Gift', 2019, '18+', '7.2/10', '69/100', 1, 1, 0, 0, 1, None, None)
# (316, 318, 'Violet Evergarden', 2018, '16+', '8.5/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (317, 319, '3Below: Tales of Arcadia', 2018, '7+', '7.7/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (318, 320, 'Jeffrey Epstein: Filthy Rich', 2020, '18+', '7.1/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (319, 321, "Dawson's Creek", 1998, '7+', '6.6/10', '69/100', 1, 1, 0, 0, 1, None, None)
# (320, 322, 'Private Practice', 2007, '16+', '6.7/10', '69/100', 1, 1, 0, 0, 1, None, None)
# (321, 323, 'Beauty and the Beast', 2012, '7+', '7.0/10', '69/100', 1, 0, 0, 1, 1, None, None)
# (322, 324, 'Daybreak', 2019, '18+', '6.7/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (323, 325, 'Easy', 2016, '18+', '6.9/10', '69/100', 1, 0, 0, 0, 1, None, None)
# (324, 326, 'Behind Her Eyes', 2021, '18+', '7.2/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (325, 327, 'Collateral', 2018, '18+', '6.8/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (326, 328, 'Knightfall', 2017, '16+', '6.8/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (327, 329, 'The Confession Killer', 2019, '16+', '7.4/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (328, 330, 'Sophie: A Murder In West Cork', 2021, '18+', '6.9/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (329, 331, 'Call My Agent!', 2015, '16+', '8.3/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (330, 332, 'My Little Pony: Friendship Is Magic', 2010, '7+', '7.6/10', '68/100', 1, 1, 0, 0, 1, None, None)
# (331, 333, 'Leah Remini: Scientology and the Aftermath', 2016, '16+', '9.0/10', '68/100', 1, 1, 0, 0, 1, None, None)
# (332, 334, 'Containment', 2016, '16+', '7.2/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (333, 335, 'Z Nation', 2014, '16+', '6.7/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (334, 336, 'Emily in Paris', 2020, '18+', '7.0/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (335, 337, 'Victorious', 2010, '7+', '6.9/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (336, 338, 'Scream: The TV Series', 2015, '16+', '7.1/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (337, 339, 'Akame ga Kill!', 2014, '18+', '7.8/10', '68/100', 1, 1, 0, 0, 1, None, None)
# (338, 340, 'Warrior Nun', 2020, '18+', '6.9/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (339, 341, 'Bad Blood', 2017, '18+', '7.5/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (340, 342, 'Young & Hungry', 2014, '16+', '7.4/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (341, 343, 'Caliphate', 2020, '18+', '8.2/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (342, 344, "'Allo 'Allo!", 1984, None, '8.3/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (343, 345, 'Good Witch', 2015, '7+', '7.3/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (344, 346, 'Gilmore Girls: A Year in the Life', 2016, '16+', '7.6/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (345, 347, 'Aquarius', 2015, '16+', '7.1/10', '68/100', 1, 0, 0, 0, 1, None, None)
# (346, 348, 'Firefly Lane', 2021, '18+', '7.4/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (347, 349, 'White Gold', 2017, '18+', '7.4/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (348, 350, 'Hyperdrive', 2019, '7+', '8.1/10', '67/100', 1, 0, 1, 0, 1, None, None)
# (349, 351, 'Reply 1988', 2015, None, '9.1/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (350, 352, 'Ninjago: Masters of Spinjitzu', 2012, 'all', '7.2/10', '67/100', 1, 0, 1, 0, 1, None, None)
# (351, 353, 'Spotless', 2015, None, '7.8/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (352, 354, 'Devilman: Crybaby', 2018, None, '7.6/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (353, 355, 'BEASTARS', 2019, '18+', '7.8/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (354, 356, 'Kill la Kill', 2013, '18+', '7.9/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (355, 357, 'Down to Earth with Zac Efron', 2020, '7+', '8.1/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (356, 358, 'Ancient Aliens', 2010, '7+', '7.2/10', '67/100', 1, 1, 1, 0, 1, None, None)
# (357, 359, 'Slasher', 2016, '18+', '6.7/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (358, 360, 'Ray', 2021, None, '7.3/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (359, 361, 'Time: The Kalief Browder Story', 2017, '16+', '8.5/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (360, 362, 'Away', 2020, '16+', '6.6/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (361, 363, 'No Tomorrow', 2016, '7+', '7.3/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (362, 364, 'Locked Up', 2015, '18+', '8.2/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (363, 365, 'The Frankenstein Chronicles', 2015, '16+', '7.3/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (364, 366, 'The Ranch', 2016, '16+', '7.5/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (365, 367, 'Cursed', 2020, '18+', '5.9/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (366, 368, 'Wu Assassins', 2019, '18+', '6.5/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (367, 369, 'Mr. Sunshine', 2018, '18+', '8.8/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (368, 370, 'The Unicorn', 2019, '7+', '7.2/10', '67/100', 1, 1, 0, 0, 1, None, None)
# (369, 371, 'Anohana: The Flower We Saw That Day', 2011, '16+', '8.2/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (370, 372, 'Alice in Borderland', 2020, None, '7.7/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (371, 373, 'The Challenge', 1998, '16+', '7.7/10', '67/100', 1, 1, 1, 0, 1, None, None)
# (372, 374, 'Gypsy', 2017, '18+', '6.8/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (373, 375, 'Fuller House', 2016, '7+', '6.7/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (374, 376, 'How to Become a Tyrant', 2021, None, '7.4/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (375, 377, 'Killer Inside: The Mind of Aaron Hernandez', 2020, '18+', '7.4/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (376, 378, 'RESIDENT EVIL: Infinite Darkness', 2021, '18+', '5.8/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (377, 379, '1983', 2018, '18+', '6.8/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (378, 380, 'Wet Hot American Summer: First Day of Camp', 2015, '16+', '7.4/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (379, 381, 'The Baker and the Beauty', 2020, '16+', '7.4/10', '67/100', 1, 0, 1, 0, 1, None, None)
# (380, 382, 'Spinning Out', 2020, '18+', '7.6/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (381, 383, 'Trinkets', 2019, '18+', '7.1/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (382, 384, 'Insatiable', 2018, '18+', '6.5/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (383, 385, 'The Chalet', 2018, '18+', '7.0/10', '67/100', 1, 0, 0, 0, 1, None, None)
# (384, 386, 'We Bare Bears', 2015, '7+', '7.9/10', '67/100', 1, 1, 0, 0, 1, None, None)
# (385, 387, 'Gurren Lagann', 2007, '16+', '8.3/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (386, 388, 'Friends from College', 2017, '18+', '6.9/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (387, 389, 'Jericho', 2006, '16+', '7.3/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (388, 390, 'Tidelands', 2018, '18+', '7.0/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (389, 391, 'Dear White People', 2017, '18+', '6.2/10', '66/100', 1, 1, 0, 0, 1, None, None)
# (390, 392, 'Dare Me', 2019, '18+', '6.7/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (391, 393, 'Ouran High School Host Club', 2006, '16+', '8.2/10', '66/100', 1, 1, 0, 0, 1, None, None)
# (392, 394, 'Scooby-Doo! Mystery Incorporated', 2010, '7+', '8.0/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (393, 395, 'The Untamed', 2019, '16+', '9.0/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (394, 396, 'Stranger', 2017, '18+', '8.6/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (395, 397, 'El Chapo', 2017, '18+', '7.8/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (396, 398, 'Great News', 2017, '7+', '7.0/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (397, 399, 'The Get Down', 2016, '16+', '8.3/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (398, 400, 'The Naked Director', 2019, '18+', '7.7/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (399, 401, 'Rise of Empires: Ottoman', 2020, '18+', '7.9/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (400, 402, 'Club de Cuervos', 2015, '18+', '8.2/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (401, 403, 'My Mister', 2018, None, '9.1/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (402, 404, 'Toradora!', 2008, '16+', '8.0/10', '66/100', 1, 0, 1, 0, 1, None, None)
# (403, 405, 'The Baby-Sitters Club', 2020, '7+', '7.4/10', '66/100', 1, 0, 1, 0, 1, None, None)
# (404, 406, 'Carole & Tuesday', 2019, '7+', '7.9/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (405, 407, 'Van Helsing', 2016, '16+', '6.2/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (406, 408, 'Vincenzo', 2021, None, '8.5/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (407, 409, 'The Night Shift', 2014, '16+', '7.4/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (408, 410, 'Pablo Escobar, The Drug Lord', 2012, '18+', '8.5/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (409, 411, 'No Game No Life', 2014, '16+', '7.8/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (410, 412, 'The King: Eternal Monarch', 2020, '16+', '8.3/10', '66/100', 1, 0, 0, 0, 1, None, None)
# (411, 413, 'Eden', 2021, '7+', '6.7/10', '65/100', 1, 0, 1, 0, 1, None, None)
# (412, 414, 'Stateless', 2020, '16+', '7.6/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (413, 415, 'High Score', 2020, '16+', '7.4/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (414, 416, 'Hospital Playlist', 2020, None, '8.7/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (415, 417, 'Dash & Lily', 2020, '7+', '8.0/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (416, 418, 'The Confession Tapes', 2017, '16+', '7.5/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (417, 419, 'Black Butler', 2008, '18+', '7.8/10', '65/100', 1, 1, 0, 0, 1, None, None)
# (418, 420, 'The Rain', 2018, '18+', '6.3/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (419, 421, 'Love Is Blind', 2020, '18+', '6.1/10', '65/100', 1, 0, 1, 0, 1, None, None)
# (420, 422, 'Trial by Media', 2020, '16+', '7.2/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (421, 423, 'Wormwood', 2017, '16+', '7.0/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (422, 424, 'Fear City: New York vs The Mafia', 2020, '18+', '7.1/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (423, 425, 'Sorjonen', 2016, '18+', '7.6/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (424, 426, 'Crashing', 2016, None, '7.7/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (425, 427, 'Forged in Fire', 2015, '7+', '8.4/10', '65/100', 1, 1, 1, 0, 1, None, None)
# (426, 428, 'Baby', 2018, '18+', '6.8/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (427, 429, 'Sweet Home', 2020, None, '7.4/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (428, 430, 'The Disastrous Life of Saiki K.', 2016, '16+', '8.3/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (429, 431, 'The Innocence Files', 2020, '18+', '8.0/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (430, 432, 'BNA', 2020, '16+', '7.2/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (431, 433, 'The Mist', 2017, '16+', '5.4/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (432, 434, 'Halston', 2021, '18+', '7.5/10', '65/100', 1, 0, 1, 0, 1, None, None)
# (433, 435, 'Shaun the Sheep', 2007, 'all', '8.2/10', '65/100', 1, 0, 1, 0, 1, None, None)
# (434, 436, 'The Universe', 2007, '16+', '8.7/10', '65/100', 1, 0, 1, 0, 1, None, None)
# (435, 437, 'Self Made: Inspired by the Life of Madam C.J. Walker', 2020, '18+', '7.3/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (436, 438, 'Shtisel', 2013, '16+', '8.6/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (437, 439, 'The Boss Baby: Back in Business', 2018, '7+', '6.5/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (438, 440, 'Puella Magi Madoka Magica', 2011, '16+', '8.3/10', '65/100', 1, 1, 0, 0, 1, None, None)
# (439, 441, 'Masameer County', 2021, None, '8.3/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (440, 442, 'Sinatra: All or Nothing at All', 2015, '7+', '8.0/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (441, 443, 'Comedians in Cars Getting Coffee', 2012, '16+', '8.1/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (442, 444, 'Senora Acero', 2014, '16+', '7.1/10', '65/100', 1, 1, 0, 0, 1, None, None)
# (443, 445, 'Dark Tourist', 2018, '18+', '7.5/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (444, 446, 'Criminal: UK', 2019, '18+', '7.6/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (445, 447, 'Heist', 2021, None, '6.8/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (446, 448, 'The Bureau of Magical Things', 2018, '7+', '6.7/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (447, 449, 'Cleverman', 2016, '16+', '6.4/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (448, 450, 'The Innocent Man', 2018, '18+', '7.3/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (449, 451, 'Norsemen', 2016, '18+', '7.8/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (450, 452, 'Word of Honor', 2021, None, '9.1/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (451, 453, 'Pawn Stars', 2009, '7+', '7.2/10', '65/100', 1, 1, 1, 0, 1, None, None)
# (452, 454, "Inside Bill's Brain: Decoding Bill Gates", 2019, '16+', '7.9/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (453, 455, 'Damnation', 2017, '18+', '7.7/10', '65/100', 1, 0, 0, 0, 1, None, None)
# (454, 456, 'From Dusk Till Dawn: The Series', 2014, '18+', '6.9/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (455, 457, 'Lovesick', 2014, '18+', '8.1/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (456, 458, 'Flint Town', 2018, '18+', '7.9/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (457, 459, 'Watership Down', 2018, '7+', '7.2/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (458, 460, 'Undercover', 2019, '18+', '7.8/10', '64/100', 1, 0, 1, 0, 1, None, None)
# (459, 461, 'Rita', 2012, '16+', '8.1/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (460, 462, 'Dorohedoro', 2020, '18+', '8.2/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (461, 463, 'Maid Sama!', 2010, '16+', '8.0/10', '64/100', 1, 1, 0, 0, 1, None, None)
# (462, 464, 'Mystery Science Theater 3000: The Return', 2017, '16+', '8.0/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (463, 465, 'Is It Wrong to Try to Pick Up Girls in a Dungeon?', 2015, '16+', '7.4/10', '64/100', 1, 1, 0, 0, 1, None, None)
# (464, 466, 'Surviving R. Kelly', 2019, '18+', '7.5/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (465, 467, 'Saint Seiya', 1986, '7+', '8.5/10', '64/100', 1, 0, 1, 0, 1, None, None)
# (466, 468, 'Flaked', 2016, '18+', '7.2/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (467, 469, 'Fate/Zero', 2011, '18+', '8.3/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (468, 470, 'Crazyhead', 2016, '16+', '7.3/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (469, 471, 'The Five', 2016, '7+', '7.6/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (470, 472, 'Signal', 2016, None, '8.6/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (471, 473, 'H2O: Just Add Water', 2006, 'all', '7.2/10', '64/100', 1, 1, 0, 0, 1, None, None)
# (472, 474, 'Requiem', 2018, '18+', '6.5/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (473, 475, 'The Valhalla Murders', 2019, '18+', '7.1/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (474, 476, 'Cardcaptor Sakura', 1998, '7+', '8.0/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (475, 477, 'Black Earth Rising', 2018, '16+', '7.5/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (476, 478, 'W/ Bob & David', 2015, '18+', '7.4/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (477, 479, 'The Trials of Gabriel Fernandez', 2020, '18+', '8.1/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (478, 480, "She's Gotta Have It", 2017, '18+', '6.8/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (479, 481, 'Save Me', 2018, '16+', '7.7/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (480, 482, 'Giri/Haji', 2019, None, '7.9/10', '64/100', 1, 0, 0, 0, 1, None, None)
# (481, 484, 'The Curse of Oak Island', 2014, '7+', '7.0/10', '64/100', 1, 1, 0, 0, 1, None, None)
# (482, 485, 'Black', 2017, '16+', '8.0/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (483, 486, 'Losers', 2019, None, '7.7/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (484, 487, 'Ajin', 2016, '18+', '7.6/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (485, 488, 'Ink Master', 2012, '16+', '7.4/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (486, 489, 'The Innocents', 2018, None, '6.3/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (487, 490, 'Goosebumps', 1995, 'all', '7.7/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (488, 491, 'Vampire Knight', 2008, '16+', '7.4/10', '63/100', 1, 1, 0, 0, 1, None, None)
# (489, 492, 'Angel Beats!', 2010, '16+', '7.7/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (490, 493, 'Green Eggs and Ham', 2019, '7+', '8.2/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (491, 494, 'The Hollow', 2018, '7+', '7.2/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (492, 495, 'Dogs', 2018, 'all', '8.1/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (493, 496, 'November 13: Attack on Paris', 2018, '18+', '8.3/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (494, 497, "It's Bruno!", 2019, '7+', '7.5/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (495, 498, 'Wanted', 2016, '16+', '7.7/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (496, 499, 'Masum', 2017, '16+', '8.4/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (497, 500, 'Cable Girls', 2017, '18+', '7.6/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (498, 501, 'Lady Dynamite', 2016, '16+', '7.4/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (499, 502, 'Power Rangers', 1993, '7+', '6.5/10', '63/100', 1, 0, 1, 0, 1, None, None)
# (500, 503, 'The Mire', 2018, '18+', '6.9/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (501, 504, 'Tabula Rasa', 2017, '18+', '8.0/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (502, 505, 'Ethos', 2020, None, '8.6/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (503, 506, 'Clannad', 2007, '7+', '7.9/10', '63/100', 1, 1, 0, 0, 1, None, None)
# (504, 507, 'Ugly Delicious', 2018, '18+', '7.8/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (505, 508, 'Generation 56k', 2021, None, '7.4/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (506, 509, 'Fate/stay night [Unlimited Blade Works]', 2014, '18+', '8.0/10', '63/100', 1, 1, 0, 0, 1, None, None)
# (507, 510, 'Man with a Plan', 2016, '7+', '7.0/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (508, 511, 'Rilakkuma and Kaoru', 2019, '7+', '8.3/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (509, 512, 'World War II In HD Colour', 2009, '7+', '8.7/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (510, 513, 'Boys Over Flowers', 2009, '16+', '7.9/10', '63/100', 1, 1, 0, 0, 1, None, None)
# (511, 514, 'Meteor Garden', 2018, '16+', '8.1/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (512, 515, "What's New, Scooby-Doo?", 2002, '7+', '7.3/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (513, 516, 'The Letdown', 2017, None, '7.5/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (514, 517, 'Sick Note', 2017, '18+', '6.8/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (515, 518, 'Big Time Rush', 2009, 'all', '6.4/10', '63/100', 1, 1, 1, 0, 1, None, None)
# (516, 519, 'Girlboss', 2017, '18+', '7.0/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (517, 520, 'Quicksand', 2019, '18+', '7.5/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (518, 521, 'Rotten', 2018, '18+', '7.2/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (519, 522, 'The Irregulars', 2021, '18+', '5.9/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (520, 523, 'The Mantis', 2017, None, '7.4/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (521, 524, 'College Romance', 2018, '18+', '8.8/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (522, 525, 'Elite Short Stories: Carla Samuel', 2021, '18+', '7.0/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (523, 526, 'Bard of Blood', 2019, '18+', '6.9/10', '63/100', 1, 0, 0, 0, 1, None, None)
# (524, 527, 'Charmed', 2018, '16+', '4.6/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (525, 528, 'The New Legends of Monkey', 2018, '7+', '6.5/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (526, 529, 'Nevertheless', 2021, None, '7.6/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (527, 530, 'The Mind, Explained', 2019, '16+', '8.0/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (528, 531, 'Fast & Furious Spy Racers', 2019, '7+', '5.5/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (529, 532, 'Itaewon Class', 2020, None, '8.2/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (530, 533, 'Occupied', 2015, '16+', '7.7/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (531, 534, 'The Magic School Bus', 1994, 'all', '7.8/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (532, 535, 'Toast of London', 2013, '16+', '8.2/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (533, 536, 'Patriot Act with Hasan Minhaj', 2018, '18+', '8.3/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (534, 537, 'Greatest Events of World War II in Colour', 2019, '16+', '8.7/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (535, 538, 'Offspring', 2010, '16+', '8.3/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (536, 539, 'Blown Away', 2019, '7+', '7.1/10', '62/100', 1, 0, 0, 0, 1, None, None)
# (537, 540, '60 Days In', 2016, '16+', '7.7/10', '62/100', 1, 1, 1, 0, 1, None, None)
# ...
# (5201, 5541, 'T.O.T.S.', 2019, 'all', '6.9/10', '50/100', 0, 0, 0, 1, 1, None, None)
# (5202, 5542, 'One Day at Disney', 2019, 'all', '7.3/10', '50/100', 0, 0, 0, 1, 1, None, None)
# (5203, 5543, 'Pixar in Real Life', 2019, 'all', '6.6/10', '50/100', 0, 0, 0, 1, 1, None, None)
# (5204, 5544, 'Mighty Ducks: The Animated Series', 1996, '7+', '6.5/10', '50/100', 0, 0, 0, 1, 1, None, None)
# (5205, 5545, 'Star Wars: Ewoks', 1985, 'all', '6.1/10', '49/100', 0, 0, 0, 1, 1, None, None)
# (5206, 5546, '101 Dalmatians: The Series', 1997, 'all', '6.2/10', '49/100', 0, 0, 0, 1, 1, None, None)
# (5207, 5548, 'Heartland Docs, DVM', 2020, None, '9.1/10', '49/100', 0, 0, 0, 1, 1, None, None)
# (5208, 5549, 'BIA', 2019, 'all', '6.7/10', '49/100', 0, 0, 0, 1, 1, None, None)
# (5209, 5550, "Marvel's Hero Project", 2019, '7+', '6.1/10', '49/100', 0, 0, 0, 1, 1, None, None)
# (5210, 5551, 'Iron Man', 1994, '7+', '6.7/10', '49/100', 0, 0, 0, 1, 1, None, None)
# (5211, 5552, 'Coop & Cami Ask The World', 2018, 'all', '5.9/10', '49/100', 0, 0, 0, 1, 1, None, None)
# (5212, 5553, 'Marvel Rising: Initiation', 2018, None, '5.3/10', '49/100', 0, 0, 0, 1, 1, None, None)
# (5213, 5554, 'My Friends Tigger & Pooh', 2007, 'all', '5.7/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5214, 5555, 'Secrets of the Zoo', 2018, None, '8.4/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5215, 5556, 'Bizaardvark', 2016, 'all', '3.7/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5216, 5558, 'The Mickey Mouse Club', 1955, 'all', '7.7/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5217, 5559, "Marvel's 616", 2020, None, '6.4/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5218, 5560, 'Turning the Tables with Robin Roberts', 2021, None, None, '48/100', 0, 0, 0, 1, 1, None, None)
# (5219, 5561, 'On Pointe', 2020, '7+', '7.7/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5220, 5562, 'Race to the Center of the Earth', 2021, None, '6.0/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5221, 5563, 'Out of the Box', 1998, 'all', '7.5/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5222, 5564, 'Gabby Duran and the Unsittables', 2019, 'all', '5.5/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5223, 5565, 'Dr. Ks Exotic Animal ER', 2014, '7+', '8.1/10', '48/100', 0, 0, 0, 1, 1, None, None)
# (5224, 5566, 'Spin and Marty', 1955, 'all', '8.1/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5225, 5567, 'Higglytown Heroes', 2004, 'all', '5.0/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5226, 5568, 'Bonkers', 1993, 'all', '6.8/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5227, 5569, 'Crash & Bernstein', 2012, 'all', '5.0/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5228, 5571, 'Lego Star Wars: The Freemaker Adventures', 2016, None, '7.4/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5229, 5573, 'Star Wars Vehicle Flythroughs', 2021, None, '6.3/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5230, 5574, 'Randy Cunningham: Ninja Total', 2012, 'all', '6.7/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5231, 5575, 'Pick of the Litter', 2019, '7+', '8.1/10', '47/100', 1, 1, 0, 1, 1, None, None)
# (5232, 5576, 'Lost Cities with Albert Lin', 2019, None, '7.8/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5233, 5577, 'Earth Moods', 2021, None, '8.2/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5234, 5578, 'Mickey and the Roadster Racers', 2017, 'all', '6.1/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5235, 5579, 'Star Wars: Forces of Destiny', 2017, 'all', '5.0/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5236, 5580, "Magic of Disney's Animal Kingdom", 2020, '7+', '8.3/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5237, 5581, 'Goldie & Bear', 2015, 'all', '6.4/10', '47/100', 0, 0, 0, 1, 1, None, None)
# (5238, 5582, 'Evermoor', 2014, None, '6.2/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5239, 5583, 'Europe From Above', 2019, None, '8.1/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5240, 5584, 'Dog: Impossible', 2019, None, '8.2/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5241, 5585, "Marvel's Ant-Man", 2017, None, '6.6/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5242, 5586, 'Adventures in Wonderland', 1992, '7+', '8.0/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5243, 5587, 'The Super Hero Squad Show', 2009, '7+', '6.1/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5244, 5588, 'Critter Fixers: Country Vets', 2020, '16+', '9.0/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5245, 5589, 'Great Migrations', 2010, 'all', '8.1/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5246, 5590, 'Origins: The Journey of Humankind', 2017, None, '6.8/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5247, 5591, 'The Lodge', 2016, None, '6.2/10', '46/100', 0, 1, 0, 1, 1, None, None)
# (5248, 5592, 'LEGO Star Wars: Droid Tales', 2015, '7+', '7.5/10', '46/100', 0, 0, 0, 1, 1, None, None)
# (5249, 5593, "Minnie's Bow-Toons", 2011, 'all', '6.2/10', '45/100', 0, 0, 0, 1, 1, None, None)
# (5250, 5594, "Chip 'n' Dale: Park Life", 2021, 'all', '6.9/10', '45/100', 0, 0, 0, 1, 1, None, None)
# (5251, 5595, 'The Book of Pooh', 2001, 'all', '6.5/10', '45/100', 0, 0, 0, 1, 1, None, None)
# (5252, 5596, 'Shark Attack Files', 2021, '16+', None, '45/100', 0, 0, 0, 1, 1, None, None)
# (5253, 5597, 'The Avengers: United They Stand', 1999, '7+', '5.5/10', '45/100', 0, 0, 0, 1, 1, None, None)
# (5254, 5598, 'Walt Disney Animation Studios: Short Circuit Experimental Films', 2020, 'all', '7.6/10', '45/100', 0, 0, 0, 1, 1, None, None)
# (5255, 5599, 'Mira, Royal Detective', 2020, 'all', '6.5/10', '45/100', 0, 0, 0, 1, 1, None, None)
# (5256, 5601, 'Legend of the Three Caballeros', 2018, 'all', '7.8/10', '45/100', 0, 0, 0, 1, 1, None, None)
# (5257, 5602, 'The Greeks', 2016, None, '7.8/10', '44/100', 0, 0, 0, 1, 1, None, None)
# (5258, 5603, "Marvel's Future Avengers", 2017, '7+', '5.7/10', '44/100', 0, 0, 0, 1, 1, None, None)
# (5259, 5604, 'Just Roll With It', 2019, '7+', '5.0/10', '44/100', 0, 0, 0, 1, 1, None, None)
# (5260, 5605, '101 Dalmatian Street', 2019, '7+', '6.3/10', '44/100', 0, 0, 0, 1, 1, None, None)
# (5261, 5606, 'Spider-Woman', 1979, 'all', '5.8/10', '44/100', 0, 0, 0, 1, 1, None, None)
# (5262, 5607, 'Primal Survivor', 2016, None, '8.3/10', '44/100', 0, 0, 0, 1, 1, None, None)
# (5263, 5608, 'Secrets of the Zoo: Tampa', 2020, None, '8.6/10', '43/100', 0, 0, 0, 1, 1, None, None)
# (5264, 5609, "Disney's Doug", 1996, None, '6.6/10', '43/100', 0, 0, 0, 1, 1, None, None)
# (5265, 5610, 'Year Million', 2017, '16+', '7.4/10', '43/100', 0, 0, 0, 1, 1, None, None)
# (5266, 5611, 'Rogue Trip', 2020, '7+', '7.2/10', '43/100', 0, 0, 0, 1, 1, None, None)
# (5267, 5612, 'Fancy Nancy', 2018, 'all', '5.5/10', '43/100', 0, 0, 0, 1, 1, None, None)
# (5268, 5613, "America's National Parks", 2015, 'all', '7.7/10', '43/100', 0, 0, 0, 1, 1, None, None)
# (5269, 5614, 'Wild Hawaii', 2014, None, '7.2/10', '43/100', 0, 0, 0, 1, 1, None, None)
# (5270, 5615, 'Lego Frozen Northern Lights', 2016, 'all', '5.7/10', '42/100', 0, 0, 0, 1, 1, None, None)
# (5271, 5616, 'Dino Ranch', 2021, 'all', '8.1/10', '42/100', 0, 0, 0, 1, 1, None, None)
# (5272, 5618, "Disney's Fairy Tale Weddings", 2017, '7+', '6.8/10', '42/100', 0, 0, 0, 1, 1, None, None)
# (5273, 5619, 'Kingdom of the Polar Bears', 2021, None, None, '42/100', 0, 0, 0, 1, 1, None, None)
# (5274, 5620, "Teacher's Pet", 2000, 'all', '6.3/10', '42/100', 0, 0, 0, 1, 1, None, None)
# (5275, 5621, 'Henry Hugglemonster', 2013, 'all', '5.3/10', '42/100', 0, 0, 0, 1, 1, None, None)
# (5276, 5622, 'Shop Class', 2020, 'all', '7.2/10', '42/100', 0, 0, 0, 1, 1, None, None)
# (5277, 5623, 'Alaska Animal Rescue', 2020, None, '9.4/10', '42/100', 0, 0, 0, 1, 1, None, None)
# (5278, 5624, 'The Rocketeer', 2019, 'all', '6.3/10', '42/100', 0, 0, 0, 1, 1, None, None)
# (5279, 5626, 'Fast Layne', 2019, 'all', '5.6/10', '41/100', 0, 0, 0, 1, 1, None, None)
# (5280, 5627, 'Weird But True!', 2016, 'all', '7.8/10', '41/100', 0, 0, 0, 1, 1, None, None)
# (5281, 5628, 'Continent 7: Antarctica', 2016, '7+', '7.4/10', '41/100', 0, 0, 0, 1, 1, None, None)
# (5282, 5629, "Marvel's Rocket & Groot", 2017, '7+', '6.8/10', '41/100', 0, 0, 0, 1, 1, None, None)
# (5283, 5630, 'Take Two with Phineas and Ferb', 2010, '7+', '6.5/10', '41/100', 0, 0, 0, 1, 1, None, None)
# (5284, 5631, 'Be our Chef', 2020, 'all', '6.3/10', '40/100', 0, 0, 0, 1, 1, None, None)
# (5285, 5632, 'Japan: Between Earth & Sky', 2018, None, '7.6/10', '40/100', 0, 0, 0, 1, 1, None, None)
# (5286, 5633, 'India from Above', 2020, None, '7.7/10', '40/100', 0, 0, 0, 1, 1, None, None)
# (5287, 5634, 'Prairie Dog Manor', 2019, None, '7.8/10', '39/100', 0, 0, 0, 1, 1, None, None)
# (5288, 5635, 'Marvel Super Hero Adventures', 2017, 'all', '6.3/10', '39/100', 0, 0, 0, 1, 1, None, None)
# (5289, 5636, 'Wild Yellowstone', 2015, None, '7.5/10', '39/100', 0, 0, 0, 1, 1, None, None)
# (5290, 5637, "Tut's Treasures: Hidden Secrets", 2018, None, '7.4/10', '39/100', 0, 0, 0, 1, 1, None, None)
# (5291, 5638, 'Secrets of the Zoo: Down Under', 2020, None, None, '39/100', 0, 0, 0, 1, 1, None, None)
# (5292, 5639, 'Disney Channel Games 2008', 2008, None, '6.7/10', '39/100', 0, 0, 0, 1, 1, None, None)
# (5293, 5640, 'UFOs: The Untold Stories', 2012, None, None, '39/100', 0, 0, 0, 1, 1, None, None)
# (5294, 5641, 'Animal ER', 2016, '16+', '8.0/10', '39/100', 0, 0, 0, 1, 1, None, None)
# (5295, 5642, 'Fury Files', 2017, None, None, '38/100', 0, 0, 0, 1, 1, None, None)
# (5296, 5643, 'Disney Parks Sunrise', 2020, None, None, '38/100', 0, 0, 0, 1, 1, None, None)
# (5297, 5644, 'Marvel Funko Shorts', 2016, 'all', None, '38/100', 0, 0, 0, 1, 1, None, None)
# (5298, 5645, 'Marvel Video Comics', 2016, 'all', '6.6/10', '38/100', 0, 0, 0, 1, 1, None, None)
# (5299, 5646, 'Secrets of Wild India', 2012, None, '8.1/10', '38/100', 0, 0, 0, 1, 1, None, None)
# (5300, 5647, 'Buried Secrets of the Bible with Albert Lin', 2019, None, '7.1/10', '38/100', 0, 0, 0, 1, 1, None, None)
# (5301, 5648, 'Supercar Megabuild', 2016, None, '4.3/10', '38/100', 0, 0, 0, 1, 1, None, None)
# (5302, 5649, 'Kirby Buckets', 2014, '7+', '4.8/10', '38/100', 0, 0, 0, 1, 1, None, None)
# (5303, 5650, 'Becoming', 2020, '16+', '6.8/10', '38/100', 1, 0, 0, 1, 1, None, None)
# (5304, 5652, 'Kingdom of the White Wolf', 2019, None, '8.1/10', '37/100', 0, 0, 0, 1, 1, None, None)
# (5305, 5653, 'Mickey Mouse Funhouse', 2021, 'all', '5.6/10', '37/100', 0, 0, 0, 1, 1, None, None)
# (5306, 5654, 'Disney Junior Music Lullabies', 2019, None, None, '37/100', 0, 0, 0, 1, 1, None, None)
# (5307, 5655, 'Wild Congo', 2014, None, None, '37/100', 0, 0, 0, 1, 1, None, None)
# (5308, 5656, 'Walk the Prank', 2016, '7+', '4.0/10', '37/100', 0, 0, 0, 1, 1, None, None)
# (5309, 5657, 'Meet the Chimps', 2020, None, '8.5/10', '37/100', 0, 0, 0, 1, 1, None, None)
# (5310, 5658, 'X-Ray Earth', 2020, None, '6.1/10', '37/100', 0, 0, 0, 1, 1, None, None)
# (5311, 5659, "It's a Dog's Life with Bill Farmer", 2020, '7+', '8.2/10', '37/100', 0, 0, 0, 1, 1, None, None)
# (5312, 5660, 'Unlikely Animal Friends', 2012, None, '7.6/10', '36/100', 0, 0, 0, 1, 1, None, None)
# (5313, 5661, 'Kingdom of the Mummies', 2020, None, '7.4/10', '36/100', 0, 0, 0, 1, 1, None, None)
# (5314, 5662, 'Wild Sri Lanka', 2015, '7+', '8.6/10', '36/100', 0, 0, 0, 1, 1, None, None)
# (5315, 5663, 'LEGO Star Wars: The Resistance Rises', 2016, None, '6.1/10', '36/100', 0, 0, 0, 1, 1, None, None)
# (5316, 5664, 'Marvel Battleworld: Mystery of the Thanostones', 2020, None, '5.9/10', '36/100', 0, 0, 0, 1, 1, None, None)
# (5317, 5665, 'Dr. T, Lone Star Vet', 2019, None, '8.4/10', '35/100', 0, 0, 0, 1, 1, None, None)
# (5318, 5666, 'Made in A Day', 2020, None, '7.6/10', '35/100', 0, 0, 0, 1, 1, None, None)
# (5319, 5667, 'Bug Juice: My Adventures at Camp', 2018, None, '7.3/10', '35/100', 0, 0, 0, 1, 1, None, None)
# (5320, 5668, "Chip 'n Dale's Nutty Tales", 2017, None, '7.0/10', '35/100', 0, 0, 0, 1, 1, None, None)
# (5321, 5669, 'Ancient China from Above', 2020, None, '7.3/10', '35/100', 0, 0, 0, 1, 1, None, None)
# (5322, 5670, 'Wild Cats of India', 2020, None, '7.6/10', '35/100', 0, 0, 0, 1, 1, None, None)
# (5323, 5671, 'Lost Treasures of the Maya', 2019, None, None, '35/100', 0, 0, 0, 1, 1, None, None)
# (5324, 5672, 'Star Wars Blips', 2017, None, '6.1/10', '34/100', 0, 0, 0, 1, 1, None, None)
# (5325, 5673, 'Birth of Europe', 2012, 'all', '7.1/10', '34/100', 0, 0, 0, 1, 1, None, None)
# (5326, 5674, "Alaska's Grizzly Gauntlet", 2018, '7+', '6.6/10', '34/100', 0, 0, 0, 1, 1, None, None)
# (5327, 5675, 'Muppet Moments', 2015, None, '8.0/10', '34/100', 0, 0, 0, 1, 1, None, None)
# (5328, 5676, "Billy Dilley's Super-Duper Subterranean Summer", 2017, '7+', '4.4/10', '34/100', 0, 0, 0, 1, 1, None, None)
# (5329, 5677, 'Mickey Go Local', 2019, None, '6.0/10', '34/100', 0, 0, 0, 1, 1, None, None)
# (5330, 5678, 'Gathering Storm', 2020, None, None, '33/100', 0, 0, 0, 1, 1, None, None)
# (5331, 5679, 'Disney Fam Jam', 2020, 'all', '5.3/10', '33/100', 0, 0, 0, 1, 1, None, None)
# (5332, 5680, 'LEGO Star Wars: All-Stars', 2018, '7+', '6.5/10', '33/100', 0, 0, 0, 1, 1, None, None)
# (5333, 5681, 'Out There with Jack Randall', 2019, None, '7.0/10', '33/100', 0, 0, 0, 1, 1, None, None)
# (5334, 5682, 'Disney Junior Music Nursery Rhymes', 2017, 'all', '6.0/10', '32/100', 0, 0, 0, 1, 1, None, None)
# (5335, 5683, 'United States of Animals', 2016, None, '6.3/10', '32/100', 0, 0, 0, 1, 1, None, None)
# (5336, 5684, 'Disney Family Sundays', 2019, 'all', '5.6/10', '31/100', 0, 0, 0, 1, 1, None, None)
# (5337, 5685, 'Rocky Mountain Animal Rescue', 2018, None, '7.9/10', '30/100', 0, 0, 0, 1, 1, None, None)
# (5338, 5686, 'Wild Nordic', 2019, None, '6.0/10', '30/100', 0, 0, 0, 1, 1, None, None)
# (5339, 5687, 'Wild Chile', 2018, '7+', '7.5/10', '30/100', 0, 0, 0, 1, 1, None, None)
# (5340, 5688, "Howie Mandel's Animals Doing Things", 2018, 'all', '3.2/10', '30/100', 0, 0, 0, 1, 1, None, None)
# (5341, 5690, 'The Big Fib', 2020, 'all', '5.4/10', '29/100', 0, 0, 0, 1, 1, None, None)
# (5342, 5691, 'Vampirina: Ghoul Girls Rock!', 2018, 'all', '7.7/10', '28/100', 0, 0, 0, 1, 1, None, None)
# (5343, 5692, 'Jungle Animal Rescue', 2020, None, '6.4/10', '28/100', 0, 0, 0, 1, 1, None, None)
# (5344, 5693, 'Disney Insider', 2012, None, None, '23/100', 0, 0, 0, 1, 1, None, None)
# (5345, 5694, 'First Class Chefs: Family Style', 2016, None, None, '23/100', 0, 0, 0, 1, 1, None, None)
# (5346, 5695, '101 Dalmatians', 1997, None, None, '21/100', 0, 0, 0, 1, 1, None, None)
# (5347, 5696, 'Spaced Out', 2019, None, None, '20/100', 0, 0, 0, 1, 1, None, None)
# (5348, 5697, 'Party Animals', 2016, 'all', None, '19/100', 0, 0, 0, 1, 1, None, None)
# (5349, 5698, 'Nature Boom Time', 2016, None, None, '18/100', 0, 0, 0, 1, 1, None, None)
# (5350, 5699, 'Lost Treasures of Egypt', 2019, None, None, '16/100', 0, 0, 0, 1, 1, None, None)
# (5351, 5700, 'What Sam Sees', 2018, None, None, '16/100', 0, 0, 0, 1, 1, None, None)
# (5352, 5701, "Scuba Sam's World", 2018, None, None, '14/100', 0, 0, 0, 1, 1, None, None)
# (5353, 5702, 'Calling All T.O.T.S.', 2020, None, None, '14/100', 0, 0, 0, 1, 1, None, None)
# (5354, 5703, 'Destination: World', 2018, None, None, '14/100', 0, 0, 0, 1, 1, None, None)
# (5355, 5704, "Sam's Zookeeper Challenge", 2019, None, None, '14/100', 0, 0, 0, 1, 1, None, None)
# (5356, 5705, 'Marvel Funko', 2017, None, None, '14/100', 0, 0, 0, 1, 1, None, None)
# (5357, 5706, 'Weirdest, Bestest, Truest', 2018, 'all', None, '14/100', 0, 0, 0, 1, 1, None, None)
# (5358, 5707, 'Roll it Back', 2019, None, None, '14/100', 0, 0, 0, 1, 1, None, None)
# (5359, 5709, 'Animal Showdown', 2018, None, None, '13/100', 0, 0, 0, 1, 1, None, None)
# (5360, 5710, 'Love & Vets', 2017, None, None, '13/100', 0, 0, 0, 1, 1, None, None)
# (5361, 5711, 'Awesome Animals', 2020, None, None, '13/100', 0, 0, 0, 1, 1, None, None)
# (5362, 5712, 'Best Job Ever', 2018, None, None, '10/100', 0, 0, 0, 1, 1, None, None)
# (5363, 5713, 'Paradise Islands', 2017, None, None, '10/100', 0, 0, 0, 1, 1, None, None)
# (5364, 5714, 'Mexico Untamed', 2018, None, None, '10/100', 0, 0, 0, 1, 1, None, None)
# (5365, 5715, 'Wild Centeral America', 2020, None, None, '10/100', 0, 0, 0, 1, 1, None, None)
# (5366, 5716, 'Wild Russia', 2018, None, None, '10/100', 0, 0, 0, 1, 1, None, None)
# (5367, 5717, 'Fearless Adventures with Jack Randall', 2018, None, None, '10/100', 0, 0, 0, 1, 1, None, None)

# %% [markdown]
# ## Results
#
# Now that you have done your analysis, make note of the answers to the following questions by editing the text cell:
#
# 1. Was every show on your watchlist in the Kaggle dataset? Do you have any ideas as to why a show might not have been present?
# 2. Did you include a show or shows in your watchlist that is exclusive to one of the platforms? How might that have impacted your analysis?
# 2. Which streaming service(s) offered the most shows on your watchlist? Which streaming service(s) offered the least?
# 3. Based on the shows you want to watch and the results of your analysis, is there a streaming service you think would be a good fit for you?
